# %%
import pandas as pd
season20_21_data = pd.read_csv("../Project_4/2020-21.csv")

# %%
season20_21_data.head(10)
# Out:
#   Div        Date   Time          HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0  E0  12/09/2020  12:30            Fulham      Arsenal     0     3   A     0
# 1  E0  12/09/2020  15:00    Crystal Palace  Southampton     1     0   H     1
# 2  E0  12/09/2020  17:30         Liverpool        Leeds     4     3   H     3
# 3  E0  12/09/2020  20:00          West Ham    Newcastle     0     2   A     0
# 4  E0  13/09/2020  14:00         West Brom    Leicester     0     3   A     0
# 5  E0  13/09/2020  16:30         Tottenham      Everton     0     1   A     0
# 6  E0  14/09/2020  20:15          Brighton      Chelsea     1     3   A     0
# 7  E0  14/09/2020  18:00  Sheffield United       Wolves     0     2   A     0
# 8  E0  19/09/2020  12:30           Everton    West Brom     5     2   H     2
# 9  E0  19/09/2020  15:00             Leeds       Fulham     4     3   H     2
#
#    HTAG  ... AvgC<2.5  AHCh  B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  \
# ...

# %%
season20_21_df = pd.DataFrame(season20_21_data)
list(season20_21_df)
# Out:
# ['Div',
#  'Date',
#  'Time',
#  'HomeTeam',
#  'AwayTeam',
#  'FTHG',
#  'FTAG',
#  'FTR',
#  'HTHG',
#  'HTAG',
#  'HTR',
#  'Referee',
#  'HS',
#  'AS',
#  'HST',
#  'AST',
#  'HF',
#  'AF',
#  'HC',
#  'AC',
#  'HY',
#  'AY',
#  'HR',
#  'AR',
#  'B365H',
#  'B365D',
#  'B365A',
#  'BWH',
#  'BWD',
#  'BWA',
#  'IWH',
#  'IWD',
#  'IWA',
#  'PSH',
#  'PSD',
#  'PSA',
#  'WHH',
#  'WHD',
#  'WHA',
#  'VCH',
#  'VCD',
#  'VCA',
#  'MaxH',
#  'MaxD',
#  'MaxA',
#  'AvgH',
#  'AvgD',
#  'AvgA',
#  'B365>2.5',
#  'B365<2.5',
#  'P>2.5',
#  'P<2.5',
#  'Max>2.5',
#  'Max<2.5',
#  'Avg>2.5',
#  'Avg<2.5',
#  'AHh',
#  'B365AHH',
#  'B365AHA',
#  'PAHH',
#  'PAHA',
#  'MaxAHH',
#  'MaxAHA',
#  'AvgAHH',
#  'AvgAHA',
#  'B365CH',
#  'B365CD',
#  'B365CA',
#  'BWCH',
#  'BWCD',
#  'BWCA',
#  'IWCH',
#  'IWCD',
#  'IWCA',
#  'PSCH',
#  'PSCD',
#  'PSCA',
#  'WHCH',
#  'WHCD',
#  'WHCA',
#  'VCCH',
#  'VCCD',
#  'VCCA',
#  'MaxCH',
#  'MaxCD',
#  'MaxCA',
#  'AvgCH',
#  'AvgCD',
#  'AvgCA',
# ...

# %%
season20_21_cleaned = season20_21_df[['Date','Time','HomeTeam','AwayTeam','FTHG','FTAG','FTR','HS',
                                       'AS','HST','AST','HF','AF','HC','AC','HY','AY','HR','AR',]]
season20_21_cleaned
# Out:
#            Date   Time          HomeTeam        AwayTeam  FTHG  FTAG FTR  HS  \
# 0    12/09/2020  12:30            Fulham         Arsenal     0     3   A   5
# 1    12/09/2020  15:00    Crystal Palace     Southampton     1     0   H   5
# 2    12/09/2020  17:30         Liverpool           Leeds     4     3   H  22
# 3    12/09/2020  20:00          West Ham       Newcastle     0     2   A  15
# 4    13/09/2020  14:00         West Brom       Leicester     0     3   A   7
# ..          ...    ...               ...             ...   ...   ...  ..  ..
# 375  23/05/2021  16:00         Liverpool  Crystal Palace     2     0   H  19
# 376  23/05/2021  16:00          Man City         Everton     5     0   H  21
# 377  23/05/2021  16:00  Sheffield United         Burnley     1     0   H  12
# 378  23/05/2021  16:00          West Ham     Southampton     3     0   H  14
# 379  23/05/2021  16:00            Wolves      Man United     1     2   A  14
#
# ...

# %%
season20_21_cleaned = season20_21_cleaned.rename(columns = {'FTHG':'Home Goals',
                                                            'FTAG':'Away Goals',
                                                            'FTR':'Winner',
                                                            'HS':'Home Team Shots',
                                                            'AS':'Away Team Shots',
                                                            'HST':'HT Shots on Target',
                                                            'AST':'AT Shots on Target',
                                                            'HF':'HT Fouls',
                                                            'AF':'AT Fouls',
                                                            'HC':'HT Corners',
                                                            'AC':'AT Corners',
                                                            'HY':'HT Yellow Cards',
                                                            'AY':'AT Yellow Cards',
                                                            'HR':'HT Red Cards',
                                                            'AR':'HT Red Cards'})
season20_21_cleaned
# Out:
#            Date   Time          HomeTeam        AwayTeam  Home Goals  \
# 0    12/09/2020  12:30            Fulham         Arsenal           0
# 1    12/09/2020  15:00    Crystal Palace     Southampton           1
# 2    12/09/2020  17:30         Liverpool           Leeds           4
# 3    12/09/2020  20:00          West Ham       Newcastle           0
# 4    13/09/2020  14:00         West Brom       Leicester           0
# ..          ...    ...               ...             ...         ...
# 375  23/05/2021  16:00         Liverpool  Crystal Palace           2
# 376  23/05/2021  16:00          Man City         Everton           5
# 377  23/05/2021  16:00  Sheffield United         Burnley           1
# 378  23/05/2021  16:00          West Ham     Southampton           3
# 379  23/05/2021  16:00            Wolves      Man United           1
#
#      Away Goals Winner  Home Team Shots  Away Team Shots  HT Shots on Target  \
# ...

# %%
season20_21_sum = season20_21_cleaned.groupby('HomeTeam').sum()
season20_21_sum.head()
# Out:
#              Home Goals  Away Goals  Home Team Shots  Away Team Shots  \
# HomeTeam
# Arsenal              24          21              240              198
# Aston Villa          29          27              269              250
# Brighton             22          22              295              151
# Burnley              14          27              197              252
# Chelsea              31          18              283              168
#
#              HT Shots on Target  AT Shots on Target  HT Fouls  AT Fouls  \
# HomeTeam
# Arsenal                      77                  54       190       214
# Aston Villa                  95                  94       232       271
# Brighton                     80                  52       228       174
# Burnley                      63                  86       186       201
# Chelsea                     112                  53       221       177
#
#              HT Corners  AT Corners  HT Yellow Cards  AT Yellow Cards  \
# HomeTeam
# ...

# %%
season20_21_cleaned.sort_values('HomeTeam', ascending=True)
# Out:
#            Date   Time HomeTeam          AwayTeam  Home Goals  Away Goals  \
# 313  18/04/2021  13:30  Arsenal            Fulham           1           1
# 244  21/02/2021  16:30  Arsenal          Man City           0           1
# 293  03/04/2021  20:00  Arsenal         Liverpool           0           3
# 199  30/01/2021  17:30  Arsenal        Man United           0           0
# 55   25/10/2020  19:15  Arsenal         Leicester           0           1
# ..          ...    ...      ...               ...         ...         ...
# 54   25/10/2020  16:30   Wolves         Newcastle           1           1
# 299  05/04/2021  20:15   Wolves          West Ham           2           3
# 312  17/04/2021  20:15   Wolves  Sheffield United           1           0
# 206  02/02/2021  18:00   Wolves           Arsenal           2           1
# 379  23/05/2021  16:00   Wolves        Man United           1           2
#
#     Winner  Home Team Shots  Away Team Shots  HT Shots on Target  \
# ...

# %%
season20_21_cleaned.to_csv('cleaned_copy1.csv')

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)

# %%
train =

# %%
test =
